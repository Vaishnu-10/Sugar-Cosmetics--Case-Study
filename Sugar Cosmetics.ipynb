# %%
# Sample Data (Replace with actual data)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Customer gender distribution data
female_customers = 52  # Replace with actual percentage or count if available
male_customers = 48  # Replace with actual percentage or count if available

# Create a list containing customer counts for each gender
customer_counts = [female_customers, male_customers]
gender_labels = ["Female", "Male"]  # Labels for the gender categories

# Create a pie chart to visualize customer segmentation
plt.figure(figsize=(6, 6))
plt.pie(customer_counts, labels=gender_labels, autopct="%1.1f%%")
plt.title("Sugar Cosmetics Customer Base Breakdown (By Gender)")
plt.axis("equal")  # Equal aspect ratio for a circular pie chart
plt.show()

# %%
# Sales channel data (replace with percentages or actual sales figures)
online_sales_percentage = 65
offline_sales_percentage = 35

# Calculate sales figures based on percentages (if actual figures not available)
total_sales = 100  # Assuming a value for total sales (replace with actual data if available)
online_sales = total_sales * (online_sales_percentage / 100)
offline_sales = total_sales * (offline_sales_percentage / 100)

sales_data = pd.DataFrame({
    "Channel": ["Online", "Offline"],
    "Sales": [online_sales, offline_sales]
})

plt.figure(figsize=(8, 6))
sns.barplot(x="Channel", y="Sales", data=sales_data)
plt.title("Sugar Cosmetics Sales Channels (2024)")
plt.xlabel("Sales Channel")
plt.ylabel("Sales")
plt.show()

# %%
# Product category and sales data (replace with percentages or actual sales figures)
product_sales_data = [
    {"Category": "Lipstick", "Sales": 30},
    {"Category": "Eyeshadow Palettes", "Sales": 25},
    {"Category": "Face Products", "Sales": 20},
    {"Category": "Other Makeup & Skincare", "Sales": 25}
]

# Convert data to a Pandas DataFrame
products = pd.DataFrame(product_sales_data)

product_sales = products.groupby("Category")["Sales"].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x="Category", y="Sales", hue="Category", data=product_sales)
plt.title("Sugar Cosmetics Product Mix (Sales Contribution, 2024)")
plt.xlabel("Product Category")
plt.ylabel("Sales")
plt.legend(title="Category", loc="upper left")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming you have website traffic data for different months (replace with actual data)
months = ["Jan", "Feb", "Mar", "Apr", "May"]
website_traffic = ['400K', '450K', '500K', '550K', '567.4K']  # Monthly website visits

plt.figure(figsize=(8, 6))
plt.plot(months, website_traffic, marker='o', linestyle='-')
plt.title("Sugar Cosmetics Website Traffic Growth (2024)")
plt.xlabel("Month")
plt.ylabel("Website Visits")
plt.grid(True)  # Add gridlines for better readability
plt.show()

# %%
sales_data = pd.DataFrame({
  "Product Category": product_categories,
  "2023 Sales": year_2023_sales,
  "2024 Sales": year_2024_sales
})

plt.figure(figsize=(10, 6))
sns.barplot(x="Product Category", y="2024 Sales", color='skyblue', data=sales_data)  # Use a color palette
plt.title("Sugar Cosmetics Product Category Sales (2024)")  # Adjust title if not showing both years
plt.xlabel("Product Category")
plt.ylabel("Sales")
plt.legend(title="Year", loc="upper left", ncol=2)  # Remove legend if not using color palette for years
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming you have data on customer acquisition channels (replace with percentages or counts)
acquisition_channels = ["Organic Search", "Paid Search", "Social Media", "Referral Traffic", "Other"]
acquisition_percentages = [70, 15, 5, 5, 5]  # Hypothetical percentages

plt.figure(figsize=(8, 8))
plt.pie(acquisition_percentages, labels=acquisition_channels, autopct="%1.1f%%")
plt.title("Sugar Cosmetics Customer Acquisition Channels")
plt.axis("equal")  # Equal aspect ratio for a circular pie chart
plt.show()

# %%
# Age group labels and percentages
age_groups = ["18-34", "35-50", "50+"]
percentages = [63.15, 25.35, 11.5]

plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=age_groups, autopct="%1.1f%%")
plt.title("Sugar Cosmetics Customer Age Distribution")
plt.axis("equal")  # Equal aspect ratio for a circular pie chart
plt.show()

# %%
# Brand names and market share percentages
brands = [
    "Maybelline (Global)",
    "L'Oreal Paris (Global)",
    "Nykaa (India)",
    "Lakmé (India)",
    "Mamaearth & WOW (India)",
    "Other Domestic Brands (India)"
]
market_share = [20, 15, 18, 12, 10, 25]

plt.figure(figsize=(10, 6))
sns.barplot(x="Market Share (%)", y=brands, data=pd.DataFrame({'Market Share (%)': market_share, 'Brands': brands}))
plt.title("Market Share in Indian Cosmetics (Estimated)")
plt.xlabel("Market Share (%)")
plt.ylabel("Brand")
plt.gca().invert_yaxis()  # Invert y-axis for readability (highest share at the top)
plt.grid(axis='x', linestyle='--', alpha=0.6)  # Add gridlines on the x-axis
plt.tight_layout()  # Adjust spacing for better readability
plt.show()

# %%
# Social media platforms and percentages
platforms = ["YouTube", "Instagram", "Facebook", "Reddit"]
percentages = [45.64, 45.17, 6.96, 2.24]

# Create a DataFrame
social_media_data = pd.DataFrame({
    "Platform": platforms,
    "Percentage": percentages
})

plt.figure(figsize=(8, 6))
sns.barplot(x="Platform", y="Percentage", data=social_media_data)
plt.title("Sugar Cosmetics Social Media Presence (Estimated)")
plt.xlabel("Platform")
plt.ylabel("Percentage")
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.6)  # Add gridlines on the y-axis
plt.tight_layout()  # Adjust spacing for better readability
plt.show()
